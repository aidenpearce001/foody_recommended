# %%
import pandas as pd 
from bs4 import BeautifulSoup
import requests
import re

# %%
df = pd.read_csv("foody_datasetC.csv")
df.head(5)
# Out:
#    Unnamed: 0             time     user_name  \
# 0           0  14/9/2017 11:45         Sunny
# 1           1  14/9/2017 11:39  Nguyên Khánh
# 2           2  14/9/2017 11:34        Tú Hảo
# 3           3  14/9/2017 11:29       Vy Nhật
# 4           4  14/9/2017 11:26        Tien97
#
#                                        user_link  \
# 0          https://www.foody.vn/thanh-vien/taiyo
# 1  https://www.foody.vn/thanh-vien/viola_0309_tv
# 2      https://www.foody.vn/thanh-vien/tuhao2509
# 3      https://www.foody.vn/thanh-vien/zip_zilip
# 4         https://www.foody.vn/thanh-vien/tien97
#
#                                           brand_name  \
# 0                  El Sol - Meat & Wine - Võ Thị Sáu
# 1  Busan Korean Food - Món Hàn Quốc - Đinh Tiên H...
# 2                     TocoToco Bubble Tea - Cộng Hòa
# 3  Le Castella Viet Nam - Bánh Bông Lan Đài Loan ...
# 4                      Tabletop - Boardgame & Coffee
#
#                                           brand_link  \
# ...

# %%
df.shape[0]
# Out:
# 174437

# %%
content = requests.get(link[128])
soup    = BeautifulSoup(content.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Gà Chicken - Gà Không Lối Thoát Online ở Quận Bắc Từ Liêm, Hà Nội | Foody.vn</title>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <meta content="Gà Chicken - Gà Không Lối Thoát Online - Shop Online - Món Việt tại Đường K2, Quận Bắc Từ Liêm, Hà Nội. Giá bình quân đầu người 299.000đ - 299.000đ" name="description"/>
# <meta content="gà chicken, gà không lối thoát, gà xôi chiên giòn, gà không lối thoát online, gà xôi chiên giòn online, gà không lối thoát định công, gà xôi chiên giòn định công" name="keywords"/>
# <meta content="app-id=1218739449" name="apple-itunes-app"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="9F288B3B53D32225CE6A70FA2DB2BF6D" name="msvalidate.01"/>
# <link href="/favicon.ico" rel="SHORTCUT ICON"/>
# ...

# %%
soup.find("div", {"class": "errorpage"})

# %%
soup.find("h1", {"itemprop": "name"}).text
# Out:
# 'Gà Chicken - Gà Không Lối Thoát Online'

# %%
rating = (soup.find("div", {"class": "microsite-point-group"}).text).replace("\n"," ")
# rating = list(dict.fromkeys(rating.split(" ")))
# rating
ratings = re.findall(r"[0-9.]+", rating)
title = re.findall(r"[A-Za-zàáãạảăắằẳẵặâấầẩẫậèéẹẻẽêềếểễệđìíĩỉịòóõọỏôốồổỗộơớờởỡợùúũụủưứừửữựỳỵỷỹýÀÁÃẠẢĂẮẰẲẴẶÂẤẦẨẪẬÈÉẸẺẼÊỀẾỂỄỆĐÌÍĨỈỊÒÓÕỌỎÔỐỒỔỖỘƠỚỜỞỠỢÙÚŨỤỦƯỨỪỬỮỰỲỴỶỸÝ]+[ ]+[A-Za-zàáãạảăắằẳẵặâấầẩẫậèéẹẻẽêềếểễệđìíĩỉịòóõọỏôốồổỗộơớờởỡợùúũụủưứừửữựỳỵỷỹýÀÁÃẠẢĂẮẰẲẴẶÂẤẦẨẪẬÈÉẸẺẼÊỀẾỂỄỆĐÌÍĨỈỊÒÓÕỌỎÔỐỒỔỖỘƠỚỜỞỠỢÙÚŨỤỦƯỨỪỬỮỰỲỴỶỸÝ]+", rating)
print(ratings)
print(title)
# rating[1::2] 
# for _ in raing:
# Out:
# []
# ['Vị trí', 'Giá cả', 'Chất lượng', 'Phục vụ', 'Không gian']

# %%
import re
position = soup.findAll('div',attrs={'class':'res-common-add'})
pos = []
for div in position:
    pos.append(div.text)
pos[0] = re.sub(r'[^ \w]', '', pos[0]).lower()
re.sub(r'[\s]+', ' ', pos[0])
# pos[0]
# Out:
# 'đường k2 quận bắc từ liêm hà nội'

# %%
test = (soup.find("div", {"class": "micro-timesopen"}).text).replace("\n"," ")
a = re.sub(r'[^ \w:]', '', test).lower()
# soup.find('span', attrs={'class':'itsopen'}).text
# '-'.join(re.findall(r"[0-9]{1,2}:[0-9]{1,2}", a))
(re.findall(r"[0-9]{1,2}:[0-9]{1,2}", a))
# Out:
# ['08:00', '23:00']

# %%
soup.find('span', attrs={'itemprop':'priceRange'}).text.replace("\n","")
# Out:
# '299.000đ - 299.000đ'

# %%
soup.find('div', attrs={'class':'ratings-boxes'}) 
# b = re.sub(r'[^ \w]', '', a).lower()
# b
# [i for i in re.sub(r'[\s]+', ' ', b).split("tiêu chí")[0].split(" ") if i.isdigit()]

# %%
link = list(dict.fromkeys(df["brand_link"]))
link = [i for i in link if "ha-noi" in i]
link[128].split('/')[-1]
# len(link)
link[128]
# Out:
# 'https://www.foody.vn/ha-noi/ga-khong-loi-thoat-688832'

# %%
cols = ["điểm chất lượng","điểm phục vụ","điểm không gian","điểm giá cả","điểm vị trí","địa điểm","thời gian mở","thời gian đóng","khoảng giá","Tổng bình luận","bình luyện tuyệt vời","bình luận tốt","bình luận trung bình","bình luận kém","Tên nhà hàng"] 
dframe = {cols[i]:[] for i in range(len(cols))}
len(dframe.keys())
# Out:
# 15

# %%
import numpy as np

for i,v in enumerate(link):
    print(i)
    content = requests.get(v)
    soup    = BeautifulSoup(content.text, "lxml")
    if soup.find("div", {"class": "errorpage"}) !=None:
        continue
    else:
        rating = (soup.find("div", {"class": "microsite-point-group"}).text).replace("\n"," ")
        ratings = re.findall(r"[0-9.]+", rating)
        ratings = [float(i) for i in ratings]
        print(len(ratings))
        if len(ratings) == 0 :
            for _ in range(5):
                dframe[cols[_]].append(None)
        else:
            for _,k in enumerate(ratings):
                if isinstance(k, float):
                    dframe[cols[_]].append(k)
                else:
                    dframe[cols[_]].append(None)
        position = soup.findAll('div',attrs={'class':'res-common-add'})
        pos = []
        for div in position:
            pos.append(div.text)
        dframe[cols[5]].append(re.sub(r'[\s]+', ' ', re.sub(r'[^ \w]', '', pos[0]).lower()))
        open_time = re.findall(r"[0-9]{1,2}:[0-9]{1,2}", re.sub(r'[^ \w:]', '', soup.find("div", {"class": "micro-timesopen"}).text).replace("\n"," "
                                                                                                                                           ).lower())
        if len(open_time) > 2 :
            opent  = open_time[0]
            closet = open_time[-1]
        elif len(open_time) == 0:
            opent  = None
            closet = None
        else:
            opent = open_time[0]
            closet = open_time[1]
        dframe[cols[6]].append(opent)
        dframe[cols[7]].append(closet)
        if soup.find('span', attrs={'itemprop':'priceRange'}) : 
            dframe[cols[8]].append(soup.find('span', attrs={'itemprop':'priceRange'}).text.replace("\n",""))
        else: 
            dframe[cols[8]].append(None)
            
        col = 9
        
        if soup.find('div', attrs={'class':'ratings-boxes'}) :
            comments = re.sub(r'[^ \w]', '', soup.find('div', attrs={'class':'ratings-boxes'}).text.replace("\n","")).lower()
            for _ in [i for i in re.sub(r'[\s]+', ' ', comments).split("tiêu chí")[0].split(" ") if i.isdigit()]:
                dframe[cols[col]].append(_)
                col +=1
        else:
            for _ in range(5):
                    dframe[cols[col]].append(None)
                    col +=1
        dframe[cols[14]].append(v.split('/')[-1])
#         print(v.split('/')[-1])
# dframe
pd.DataFrame(dframe)
# Out:
# 0
# 5
# 1
# 5
# 2
# 3
# 5
# 4
# 5
# 5
# 5
# 6
# 5
# 7
# 5
# 8
# 5
# 9
# 10
# 5
# 11
# 12
# 13
# 5
# 14
# 5
# 15
# 5
# 16
# 5
# 17
# 5
# 18
# 5
# 19
# 5
# 20
# 5
# 21
# 22
# 5
# 23
# 5
# 24
# 25
# 5
# 26
# 5
# 27
# 28
# 5
# 29
# 30
# 5
# 31
# 5
# 32
# 5
# 33
# 5
# 34
# 5
# 35
# 36
# 5
# 37
# 5
# 38
# 5
# 39
# 40
# 5
# 41
# 5
# 42
# 43
# 5
# 44
# 45
# 5
# 46
# 5
# 47
# 48
# 5
# 49
# 5
# 50
# 5
# 51
# 5
# 52
# 5
# 53
# 5
# 54
# 5
# 55
# 5
# 56
# 57
# 5
# 58
# 5
# 59
# 5
# 60
# 61
# 62
# 63
# 5
# 64
# 65
# 66
# 5
# 67
# 5
# 68
# 5
# 69
# 5
# 70
# 5
# 71
# 72
# 5
# 73
# 74
# 75
# 5
# 76
# 5
# 77
# 5
# 78
# 5
# 79
# 80
# 5
# 81
# 5
# 82
# 5
# 83
# 84
# 5
# 85
# 5
# 86
# 5
# 87
# 5
# 88
# 5
# 89
# 5
# 90
# 5
# 91
# 5
# 92
# 5
# 93
# 5
# 94
# 5
# 95
# 5
# 96
# 5
# 97
# 98
# 5
# 99
# 5
# 100
# 5
# 101
# 5
# 102
# 5
# 103
# 5
# 104
# 5
# 105
# 5
# 106
# 5
# 107
# 5
# 108
# 5
# 109
# 110
# 5
# 111
# 5
# 112
# 113
# 5
# 114
# 5
# 115
# 5
# 116
# 117
# 5
# 118
# 119
# 5
# 120
# 5
# 121
# 122
# 5
# ...

# %%
link[43]
# Out:
# 'https://www.foody.vn/ha-noi/long-heo-dac-biet-nguyen-thi-dinh'

# %%
df.tail()
# Out:
#         Unnamed: 0             time             user_name  \
# 174432      204384   28/8/2016 5:39  Leng Keng Chuông Gió
# 174433      204385  27/8/2016 13:19            Linh Giang
# 174434      204386   27/8/2016 9:59        Con Chim Non 🐣
# 174435      204387   27/8/2016 9:47        Con Chim Non 🐣
# 174436      204388   27/8/2016 9:39        Con Chim Non 🐣
#
#                                                 user_link  \
# 174432  https://www.foody.vn/thanh-vien/muathuyeuthuon...
# 174433    https://www.foody.vn/thanh-vien/giang.nguyen050
# 174434     https://www.foody.vn/thanh-vien/chaunguyenbach
# 174435     https://www.foody.vn/thanh-vien/chaunguyenbach
# 174436     https://www.foody.vn/thanh-vien/chaunguyenbach
#
#                      brand_name                                   brand_link  \
# 174432  한국관 - Nhà Hàng Hàn Quốc  https://www.foody.vn/hue/-nha-hang-han-quoc
# 174433  한국관 - Nhà Hàng Hàn Quốc  https://www.foody.vn/hue/-nha-hang-han-quoc
# ...

# %%
for i,v in dframe.items():
    print(len(v))
# Out:
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149
# 149

# %%
pd.DataFrame(dframe).to_csv('new.csv',index = False,encoding='utf-8-sig')

# %%
dframe['điểm chất lượng'].append('1') 
dframe['điểm chất lượng']
# Out:
# ['1', '1']

# %%
for i in [None]*5:
    print(i)
# Out:
# None
# None
# None
# None
# None
